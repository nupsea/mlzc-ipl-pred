# %%
import pandas as pd 
import numpy as np 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('../DATA/all_season_summary.csv')

# %% [markdown]
# ### EDA

# %%
df.head(10)
# Out:
#    season       id                                                 name  \
# 0  2023.0  1359475                 Gujarat Titans v Chennai Super Kings
# 1  2023.0  1359476                 Punjab Kings v Kolkata Knight Riders
# 2  2023.0  1359477                Lucknow Super Giants v Delhi Capitals
# 3  2023.0  1359478               Sunrisers Hyderabad v Rajasthan Royals
# 4  2023.0  1359479         Royal Challengers Bangalore v Mumbai Indians
# 5  2023.0  1359480           Chennai Super Kings v Lucknow Super Giants
# 6  2023.0  1359481                      Delhi Capitals v Gujarat Titans
# 7  2023.0  1359482                      Rajasthan Royals v Punjab Kings
# 8  2023.0  1359483  Kolkata Knight Riders v Royal Challengers Bangalore
# 9  2023.0  1359484           Lucknow Super Giants v Sunrisers Hyderabad
#
#    short_name  \
# 0    GT v CSK
# 1  PBKS v KKR
# 2    LSG v DC
# 3    SRH v RR
# 4    RCB v MI
# 5   CSK v LSG
# 6     DC v GT
# 7   RR v PBKS
# 8   KKR v RCB
# 9   LSG v SRH
#
#                                                         description home_team  \
# 0    1st Match (N), Indian Premier League at Ahmedabad, Mar 31 2023        GT
# 1  2nd Match (D/N), Indian Premier League at Chandigarh, Apr 1 2023      PBKS
# 2       3rd Match (N), Indian Premier League at Lucknow, Apr 1 2023       LSG
# 3   4th Match (D/N), Indian Premier League at Hyderabad, Apr 2 2023       SRH
# 4     5th Match (N), Indian Premier League at Bengaluru, Apr 2 2023       RCB
# 5       6th Match (N), Indian Premier League at Chennai, Apr 3 2023       CSK
# 6         7th Match (N), Indian Premier League at Delhi, Apr 4 2023        DC
# 7      8th Match (N), Indian Premier League at Guwahati, Apr 5 2023        RR
# 8       9th Match (N), Indian Premier League at Kolkata, Apr 6 2023       KKR
# 9      10th Match (N), Indian Premier League at Lucknow, Apr 7 2023       LSG
#
#   away_team toss_won    decision 1st_inning_score 2nd_inning_score home_score  \
# 0       CSK       GT  BOWL FIRST            178/7            182/5      182/5
# 1       KKR      KKR  BOWL FIRST            191/5            146/7      191/5
# 2        DC       DC  BOWL FIRST            193/6            143/9      193/6
# 3        RR      SRH  BOWL FIRST            203/5            131/8      131/8
# 4        MI      RCB  BOWL FIRST            171/7            172/2      172/2
# 5       LSG      LSG  BOWL FIRST            217/7            205/7      217/7
# 6        GT       GT  BOWL FIRST            162/8            163/4      162/8
# 7      PBKS       RR  BOWL FIRST            197/4            192/7      192/7
# 8       RCB      RCB  BOWL FIRST            204/7              123      204/7
# 9       SRH      SRH   BAT FIRST            121/8            127/5      127/5
#
#   away_score winner                                result         start_date  \
# 0      178/7     GT         Titans won by 5 wkts (4b rem)  2023-03-31T14:00Z
# 1      146/7   PBKS      Punjab Kings won by 7 runs (DLS)  2023-04-01T10:00Z
# 2      143/9    LSG           Super Giants won by 50 runs  2023-04-01T14:00Z
# 3      203/5     RR                 Royals won by 72 runs  2023-04-02T10:00Z
# 4      171/7    RCB           RCB won by 8 wkts (22b rem)  2023-04-02T14:00Z
# 5      205/7    CSK            Super Kings won by 12 runs  2023-04-03T14:00Z
# 6      163/4     GT        Titans won by 6 wkts (11b rem)  2023-04-04T14:00Z
# 7      197/4   PBKS            Punjab Kings won by 5 runs  2023-04-05T14:00Z
# 8        123    KKR                    KKR won by 81 runs  2023-04-06T14:00Z
# 9      121/8    LSG  Super Giants won by 5 wkts (24b rem)  2023-04-07T14:00Z
#
#             end_date  venue_id  \
# 0  2023-04-01T23:59Z     57851
# 1  2023-04-02T23:59Z     57991
# 2  2023-04-02T23:59Z   1070094
# 3  2023-04-03T23:59Z     58142
# 4  2023-04-03T23:59Z     57897
# 5  2023-04-04T23:59Z     58008
# 6  2023-04-05T23:59Z     58040
# 7  2023-04-06T23:59Z    680295
# 8  2023-04-07T23:59Z     57980
# 9  2023-04-08T23:59Z   1070094
#
#                                                               venue_name  \
# 0                               Narendra Modi Stadium, Motera, Ahmedabad
# 1       Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh
# 2  Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow
# 3                   Rajiv Gandhi International Stadium, Uppal, Hyderabad
# 4                                       M.Chinnaswamy Stadium, Bengaluru
# 5                               MA Chidambaram Stadium, Chepauk, Chennai
# 6                                            Arun Jaitley Stadium, Delhi
# 7                                    Barsapara Cricket Stadium, Guwahati
# 8                                                  Eden Gardens, Kolkata
# 9  Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow
#
#         home_captain    away_captain             pom  \
# 0      Hardik Pandya        MS Dhoni     Rashid Khan
# 1     Shikhar Dhawan     Nitish Rana  Arshdeep Singh
# 2           KL Rahul    David Warner       Mark Wood
# 3  Bhuvneshwar Kumar    Sanju Samson     Jos Buttler
# 4     Faf du Plessis    Rohit Sharma  Faf du Plessis
# 5           MS Dhoni        KL Rahul       Moeen Ali
# 6       David Warner   Hardik Pandya   Sai Sudharsan
# 7       Sanju Samson  Shikhar Dhawan    Nathan Ellis
# 8        Nitish Rana  Faf du Plessis  Shardul Thakur
# 9           KL Rahul   Aiden Markram   Krunal Pandya
#
#                                                    points super_over  \
# 0                 Gujarat Titans 2, Chennai Super Kings 0      False
# 1                 Punjab Kings 2, Kolkata Knight Riders 0      False
# 2                Lucknow Super Giants 2, Delhi Capitals 0      False
# 3               Rajasthan Royals 2, Sunrisers Hyderabad 0      False
# 4         Royal Challengers Bangalore 2, Mumbai Indians 0      False
# 5           Chennai Super Kings 2, Lucknow Super Giants 0      False
# 6                      Gujarat Titans 2, Delhi Capitals 0      False
# 7                      Punjab Kings 2, Rajasthan Royals 0      False
# 8  Kolkata Knight Riders 2, Royal Challengers Bangalore 0      False
# 9           Lucknow Super Giants 2, Sunrisers Hyderabad 0      False
#
#    home_overs  home_runs  home_wickets  home_boundaries  away_overs  \
# 0        19.2      182.0           5.0             23.0        20.0
# 1        20.0      191.0           5.0             26.0        16.0
# 2        20.0      193.0           6.0             21.0        20.0
# 3        20.0      131.0           8.0             13.0        20.0
# 4        16.2      172.0           2.0             24.0        20.0
# 5        20.0      217.0           7.0             28.0        20.0
# 6        20.0      162.0           8.0             20.0        18.1
# 7        20.0      192.0           7.0             23.0        20.0
# 8        20.0      204.0           7.0             27.0        17.4
# 9        16.0      127.0           5.0             16.0        20.0
#
#    away_runs  away_wickets  away_boundaries  \
# 0      178.0           7.0             23.0
# 1      146.0           7.0             20.0
# 2      143.0           9.0             17.0
# 3      203.0           5.0             29.0
# 4      171.0           7.0             22.0
# 5      205.0           7.0             22.0
# 6      163.0           4.0             20.0
# 7      197.0           4.0             26.0
# 8      123.0          10.0             16.0
# 9      121.0           8.0             13.0
#
#                                                                                                                                                                                      highlights  \
# 0                           Gill, Rashid lead defending champions Gujarat Titans to victory in IPL 2023 opener. Ruturaj Gaikwad scored 92 but Chennai Super Kings managed only 178 in Ahmedabad
# 1  Arshdeep, Rajapaksa lead Punjab Kings to victory in rain-hit game. Knight Riders, behind for most parts of the game, almost got to the DLS target thanks to Andre Russell and Venkatesh Iyer
# 2                                                     Wood five-for, Mayers 73 stud Super Giants' win. Capitals struggled against Super Giants' bowlers in the 194 chase on a challenging pitch
# 3                                           Buttler and Boult trigger demolition of Sunrisers. Samson and Jaiswal scored fifties, and Chahal took a four-wicket haul, in Royals' 72-run victory
# 4                         Virat Kohli, Faf du Plessis help RCB brush aside Mumbai Indians. Tilak Varma's unbeaten 84 was the only positive for Mumbai as RCB romped home with 22 balls to spare
# 5                                        Gaikwad, Conway and Moeen give CSK a happy homecoming. They powered their way to 217 before the spinners strangled Lucknow Super Giants in their chase
# 6                                  Sai Sudharsan sees Titans home after their quicks restrict Delhi Capitals. The defending champions have opened their title defence with two consecutive wins
# 7           Dhawan, Ellis and Prabhsimran help Kings survive Impact Sub scare. The Royals youngster Jurel almost won it for them in the end as he went on a boundary-hitting spree with Hetmyer
# 8                                        Shardul and spinners dismantle RCB. Coming in at 89 for 5, Shardul smashed 68 off 29 before Narine, Varun and Suyash derailed Royal Challengers' chase
# 9                                    Krunal's all-round display helps LSG brush Sunrisers aside. Mishra and Bishnoi also played their part in strangling Sunrisers on a slow, low Ekana surface
#
#                     home_key_batsman                   home_key_bowler  \
# 0         Shubman Gill,Vijay Shankar        Rashid Khan,Mohammed Shami
# 1   Bhanuka Rajapaksa,Shikhar Dhawan       Arshdeep Singh,Rahul Chahar
# 2        Kyle Mayers,Nicholas Pooran              Mark Wood,Avesh Khan
# 3         Abdul Samad,Mayank Agarwal      T Natarajan,Fazalhaq Farooqi
# 4         Virat Kohli,Faf du Plessis          Karn Sharma,Reece Topley
# 5       Ruturaj Gaikwad,Devon Conway        Moeen Ali,Tushar Deshpande
# 6            David Warner,Axar Patel      Anrich Nortje,Mitchell Marsh
# 7       Sanju Samson,Shimron Hetmyer  Jason Holder,Ravichandran Ashwin
# 8  Shardul Thakur,Rahmanullah Gurbaz  Varun Chakravarthy,Suyash Sharma
# 9             KL Rahul,Krunal Pandya         Krunal Pandya,Amit Mishra
#
#                                                                                                                                                                                                                                      home_playx1  \
# 0           Wriddhiman Saha (WK),Shubman Gill (UKN),Sai Sudharsan (UKN),Hardik Pandya (AR),Vijay Shankar (AR),Rahul Tewatia (AR),Rashid Khan (AR),Mohammed Shami (BL),Josh Little (BL),Yash Dayal (BL),Alzarri Joseph (BL),Kane Williamson (UKN)
# 1  Prabhsimran Singh (UKN),Shikhar Dhawan (UKN),Bhanuka Rajapaksa (UKN),Jitesh Sharma (WK),Sikandar Raza (AR),Sam Curran (AR),M Shahrukh Khan (UKN),Harpreet Brar (BL),Rahul Chahar (BL),Arshdeep Singh (BL),Nathan Ellis (BL),Rishi Dhawan (AR)
# 2                  KL Rahul (UKN),Kyle Mayers (AR),Deepak Hooda (AR),Krunal Pandya (AR),Marcus Stoinis (AR),Nicholas Pooran (WK),Ayush Badoni (UKN),Krishnappa Gowtham (AR),Avesh Khan (BL),Ravi Bishnoi (BL),Jaydev Unadkat (BL),Mark Wood (BL)
# 3  Abhishek Sharma (AR),Mayank Agarwal (UKN),Rahul Tripathi (UKN),Harry Brook (UKN),Washington Sundar (AR),Glenn Phillips (WK),Abdul Samad (UKN),Adil Rashid (BL),Bhuvneshwar Kumar (BL),Umran Malik (BL),T Natarajan (BL),Fazalhaq Farooqi (BL)
# 4                              Virat Kohli (UKN),Faf du Plessis (UKN),Dinesh Karthik (WK),Glenn Maxwell (AR),Michael Bracewell (AR),Shahbaz Ahmed (AR),Harshal Patel (BL),Akash Deep (AR),Reece Topley (BL),Mohammed Siraj (BL),Karn Sharma (BL)
# 5     Ruturaj Gaikwad (UKN),Devon Conway (UKN),Shivam Dube (AR),Moeen Ali (AR),Ben Stokes (AR),Ambati Rayudu (UKN),Ravindra Jadeja (AR),MS Dhoni (WK),Mitchell Santner (AR),Deepak Chahar (BL),Rajvardhan Hangargekar (AR),Tushar Deshpande (BL)
# 6           David Warner (UKN),Prithvi Shaw (UKN),Mitchell Marsh (AR),Sarfaraz Khan (UKN),Rilee Rossouw (UKN),Abishek Porel (WK),Axar Patel (AR),Aman Hakim Khan (AR),Kuldeep Yadav (BL),Anrich Nortje (BL),Mukesh Kumar (BL),Khaleel Ahmed (BL)
# 7     Yashasvi Jaiswal (UKN),Ravichandran Ashwin (AR),Jos Buttler (UKN),Sanju Samson (WK),Devdutt Padikkal (UKN),Riyan Parag (UKN),Shimron Hetmyer (UKN),Dhruv Jurel (UKN),Jason Holder (AR),Trent Boult (BL),KM Asif (BL),Yuzvendra Chahal (BL)
# 8       Rahmanullah Gurbaz (WK),Venkatesh Iyer (AR),Mandeep Singh (AR),Nitish Rana (UKN),Rinku Singh (UKN),Andre Russell (AR),Shardul Thakur (BL),Sunil Narine (AR),Umesh Yadav (BL),Tim Southee (BL),Varun Chakravarthy (BL),Suyash Sharma (BL)
# 9                 Kyle Mayers (AR),KL Rahul (UKN),Deepak Hooda (AR),Krunal Pandya (AR),Marcus Stoinis (AR),Romario Shepherd (AR),Nicholas Pooran (WK),Yash Thakur (BL),Jaydev Unadkat (BL),Ravi Bishnoi (BL),Ayush Badoni (UKN),Amit Mishra (BL)
#
#                                                                                                                                                                                                                                       away_playx1  \
# 0      Devon Conway (UKN),Ruturaj Gaikwad (UKN),Moeen Ali (AR),Ben Stokes (AR),Ambati Rayudu (UKN),Shivam Dube (AR),Ravindra Jadeja (AR),MS Dhoni (WK),Mitchell Santner (AR),Deepak Chahar (BL),Rajvardhan Hangargekar (AR),Tushar Deshpande (BL)
# 1           Mandeep Singh (AR),Rahmanullah Gurbaz (WK),Anukul Roy (AR),Venkatesh Iyer (AR),Nitish Rana (UKN),Rinku Singh (UKN),Andre Russell (AR),Shardul Thakur (BL),Sunil Narine (AR),Tim Southee (BL),Umesh Yadav (BL),Varun Chakravarthy (BL)
# 2          Prithvi Shaw (UKN),David Warner (UKN),Mitchell Marsh (AR),Sarfaraz Khan (WK),Rilee Rossouw (UKN),Rovman Powell (UKN),Aman Hakim Khan (AR),Axar Patel (AR),Kuldeep Yadav (BL),Chetan Sakariya (BL),Mukesh Kumar (BL),Khaleel Ahmed (BL)
# 3     Yashasvi Jaiswal (UKN),Jos Buttler (UKN),Sanju Samson (WK),Devdutt Padikkal (UKN),Riyan Parag (UKN),Shimron Hetmyer (UKN),Ravichandran Ashwin (AR),Jason Holder (AR),Trent Boult (BL),KM Asif (BL),Yuzvendra Chahal (BL),Navdeep Saini (BL)
# 4           Rohit Sharma (UKN),Ishan Kishan (WK),Cameron Green (AR),Suryakumar Yadav (UKN),Tilak Varma (AR),Nehal Wadhera (UKN),Tim David (UKN),Hrithik Shokeen (BL),Arshad Khan (BL),Piyush Chawla (AR),Jofra Archer (BL),Jason Behrendorff (BL)
# 5                      KL Rahul (UKN),Kyle Mayers (AR),Deepak Hooda (AR),Krunal Pandya (AR),Marcus Stoinis (AR),Nicholas Pooran (WK),Ayush Badoni (UKN),Krishnappa Gowtham (AR),Mark Wood (BL),Yash Thakur (BL),Ravi Bishnoi (BL),Avesh Khan (BL)
# 6               Wriddhiman Saha (WK),Shubman Gill (UKN),Sai Sudharsan (UKN),Hardik Pandya (AR),Vijay Shankar (AR),David Miller (UKN),Rahul Tewatia (AR),Rashid Khan (AR),Alzarri Joseph (BL),Yash Dayal (BL),Mohammed Shami (BL),Josh Little (BL)
# 7   Prabhsimran Singh (UKN),Shikhar Dhawan (UKN),Bhanuka Rajapaksa (UKN),Jitesh Sharma (WK),Sikandar Raza (AR),M Shahrukh Khan (UKN),Sam Curran (AR),Harpreet Brar (BL),Nathan Ellis (BL),Rahul Chahar (BL),Arshdeep Singh (BL),Rishi Dhawan (AR)
# 8              Virat Kohli (UKN),Faf du Plessis (UKN),Michael Bracewell (AR),Glenn Maxwell (AR),Harshal Patel (BL),Shahbaz Ahmed (AR),Dinesh Karthik (WK),Anuj Rawat (UKN),David Willey (AR),Karn Sharma (BL),Akash Deep (AR),Mohammed Siraj (BL)
# 9  Anmolpreet Singh (WK),Mayank Agarwal (UKN),Rahul Tripathi (UKN),Aiden Markram (UKN),Harry Brook (UKN),Washington Sundar (AR),Abdul Samad (UKN),Adil Rashid (BL),Umran Malik (BL),Bhuvneshwar Kumar (BL),T Natarajan (BL),Fazalhaq Farooqi (BL)
#
#                    away_key_batsman                         away_key_bowler  \
# 0         Ruturaj Gaikwad,Moeen Ali  Rajvardhan Hangargekar,Ravindra Jadeja
# 1      Andre Russell,Venkatesh Iyer          Tim Southee,Varun Chakravarthy
# 2        David Warner,Rilee Rossouw           Khaleel Ahmed,Chetan Sakariya
# 3     Sanju Samson,Yashasvi Jaiswal            Yuzvendra Chahal,Trent Boult
# 4         Tilak Varma,Nehal Wadhera               Arshad Khan,Cameron Green
# 5       Kyle Mayers,Nicholas Pooran                  Ravi Bishnoi,Mark Wood
# 6        Sai Sudharsan,David Miller              Rashid Khan,Mohammed Shami
# 7  Shikhar Dhawan,Prabhsimran Singh             Nathan Ellis,Arshdeep Singh
# 8        Faf du Plessis,Virat Kohli                David Willey,Karn Sharma
# 9   Rahul Tripathi,Anmolpreet Singh            Adil Rashid,Fazalhaq Farooqi
#
#                                         match_days                umpire1  \
# 0      31 March 2023 - night match (20-over match)          Saiyed Khalid
# 1  01 April 2023 - day/night match (20-over match)         Yeshwant Barde
# 2      01 April 2023 - night match (20-over match)         Anil Chaudhary
# 3  02 April 2023 - day/night match (20-over match)  KN Ananthapadmanabhan
# 4      02 April 2023 - night match (20-over match)            Nitin Menon
# 5      03 April 2023 - night match (20-over match)         Bruce Oxenford
# 6      04 April 2023 - night match (20-over match)           Nand Kishore
# 7      05 April 2023 - night match (20-over match)  KN Ananthapadmanabhan
# 8      06 April 2023 - night match (20-over match)        Virender Sharma
# 9      07 April 2023 - night match (20-over match)         Yeshwant Barde
#
#                  umpire2              tv_umpire          referee  \
# 0            Nitin Menon        Virender Sharma  Javagal Srinath
# 1         Bruce Oxenford  Jayaraman Madanagopal      Manu Nayyar
# 2      Nikhil Patwardhan          Sadashiv Iyer   Daniel Manohar
# 3           Rohan Pandit          Navdeep Singh  Narayanan Kutty
# 4           Tapan Sharma        Virender Sharma  Javagal Srinath
# 5           Akshay Totre           Ulhas Gandhe      Manu Nayyar
# 6          Sadashiv Iyer         Anil Chaudhary   Daniel Manohar
# 7      Saidharshan Kumar           Rohan Pandit  Narayanan Kutty
# 8           Vinod Seshan            Nitin Menon     Shakti Singh
# 9  Jayaraman Madanagopal         Bruce Oxenford      Manu Nayyar
#
#          reserve_umpire
# 0       Abhijit Bengeri
# 1          Pranav Joshi
# 2  Madanagopal Kuppuraj
# 3  Abhijit Bhattacharya
# 4       Abhijit Bengeri
# 5          Pranav Joshi
# 6  Madanagopal Kuppuraj
# 7  Abhijit Bhattacharya
# 8       Abhijit Bengeri
# 9          Pranav Joshi

# %%
df.columns
# Out:
# Index(['season', 'id', 'name', 'short_name', 'description', 'home_team',
#        'away_team', 'toss_won', 'decision', '1st_inning_score',
#        '2nd_inning_score', 'home_score', 'away_score', 'winner', 'result',
#        'start_date', 'end_date', 'venue_id', 'venue_name', 'home_captain',
#        'away_captain', 'pom', 'points', 'super_over', 'home_overs',
#        'home_runs', 'home_wickets', 'home_boundaries', 'away_overs',
#        'away_runs', 'away_wickets', 'away_boundaries', 'highlights',
#        'home_key_batsman', 'home_key_bowler', 'home_playx1', 'away_playx1',
#        'away_key_batsman', 'away_key_bowler', 'match_days', 'umpire1',
#        'umpire2', 'tv_umpire', 'referee', 'reserve_umpire'],
#       dtype='object')

# %% [markdown]
# * column names are already standardized.

# %%
# cols_of_interest = ['season', 'name', 'description', 'home_team', 'away_team',]

mdf = df.copy()


mdf['output'] = (mdf['home_team'] == mdf['winner']).astype(int)
mdf['run_rate'] = mdf['home_runs'] / mdf['home_overs']
mdf['bowl_econ'] = mdf['away_runs'] / mdf['away_overs']

mdf[['season_match', 'day_night_play']] = mdf.description.str.extract(r'^(.*?)\s*\(([^)]*)\)')

# %%
def h2h(df):
    df = df.sort_values('start_date')  # Ensure time order

    df = df.sort_values(by=['short_name', 'start_date'])

    df['shifted_home_win'] = df.groupby('short_name')['output'].shift(1)

    df['h2h_home_win_ratio_last_10'] = (
        df.groupby('short_name')['shifted_home_win']
        .rolling(window=10, min_periods=1)
        .mean()
        .reset_index(level=0, drop=True)
    )

    df['shifted_runs'] = df.groupby('short_name')['home_runs'].shift(1) 

    df['h2h_avg_runs_last_10'] = (
        df.groupby('short_name')['shifted_runs']
        .rolling(window=10, min_periods=1)
        .mean()
        .reset_index(level=0, drop=True)
    )
    return df

# %%
mdf = h2h(mdf)
mdf[mdf.home_team == 'RCB'].head()
# Out:
#      season      id                                               name  \
# 987  2008.0  335996  Royal Challengers Bangalore v Chennai Super Kings
# 918  2009.0  392185  Royal Challengers Bangalore v Chennai Super Kings
# 957  2009.0  392224  Royal Challengers Bangalore v Chennai Super Kings
# 871  2010.0  419123  Royal Challengers Bangalore v Chennai Super Kings
# 848  2011.0  501266  Royal Challengers Bangalore v Chennai Super Kings
#
#     short_name  \
# 987  RCB v CSK
# 918  RCB v CSK
# 957  RCB v CSK
# 871  RCB v CSK
# 848  RCB v CSK
#
#                                                                description  \
# 987        15th match (N), Indian Premier League at Bengaluru, Apr 28 2008
# 918  5th match (D/N), Indian Premier League at Port Elizabeth, Apr 20 2009
# 957               44th match, Indian Premier League at Durban, May 14 2009
# 871        18th match (N), Indian Premier League at Bengaluru, Mar 23 2010
# 848      69th match (D/N), Indian Premier League at Bengaluru, May 22 2011
#
#     home_team away_team toss_won    decision 1st_inning_score  \
# 987       RCB       CSK      CSK   BAT FIRST            178/5
# 918       RCB       CSK      CSK   BAT FIRST            179/5
# 957       RCB       CSK      CSK   BAT FIRST              129
# 871       RCB       CSK      CSK  BOWL FIRST            171/5
# 848       RCB       CSK      RCB  BOWL FIRST            128/8
#
#     2nd_inning_score home_score away_score winner  \
# 987              165        165      178/5    CSK
# 918               87         87      179/5    CSK
# 957            132/8      132/8        129    RCB
# 871            135/7      171/5      135/7    RCB
# 848            129/2      129/2      128/8    RCB
#
#                                              result         start_date  \
# 987                      Super Kings won by 13 runs  2008-04-28T14:30Z
# 918                      Super Kings won by 92 runs  2009-04-20T14:30Z
# 957   RCB won by 2 wickets (with 2 balls remaining)  2009-05-14T10:30Z
# 871                              RCB won by 36 runs  2010-03-23T14:30Z
# 848  RCB won by 8 wickets (with 12 balls remaining)  2011-05-22T10:30Z
#
#               end_date  venue_id                        venue_name  \
# 987  2008-04-30T23:59Z     57897  M.Chinnaswamy Stadium, Bengaluru
# 918  2009-04-22T23:59Z     59159  St George's Park, Port Elizabeth
# 957  2009-05-16T23:59Z     59089                 Kingsmead, Durban
# 871  2010-03-25T23:59Z     57897  M.Chinnaswamy Stadium, Bengaluru
# 848  2011-05-24T23:59Z     57897  M.Chinnaswamy Stadium, Bengaluru
#
#         home_captain  away_captain                   pom  \
# 987     Rahul Dravid      MS Dhoni              MS Dhoni
# 918  Kevin Pietersen      MS Dhoni  Muttiah Muralitharan
# 957      Anil Kumble      MS Dhoni           Ross Taylor
# 871      Anil Kumble  Suresh Raina         Robin Uthappa
# 848   Daniel Vettori      MS Dhoni           Chris Gayle
#
#                                                    points super_over  \
# 987  Chennai Super Kings 2, Royal Challengers Bangalore 0      False
# 918  Chennai Super Kings 2, Royal Challengers Bangalore 0      False
# 957  Royal Challengers Bangalore 2, Chennai Super Kings 0      False
# 871  Royal Challengers Bangalore 2, Chennai Super Kings 0      False
# 848  Royal Challengers Bangalore 2, Chennai Super Kings 0      False
#
#      home_overs  home_runs  home_wickets  home_boundaries  away_overs  \
# 987        19.4      165.0          10.0             19.0        20.0
# 918        15.2       87.0          10.0             10.0        20.0
# 957        19.4      132.0           8.0             15.0        19.4
# 871        20.0      171.0           5.0             22.0        20.0
# 848        18.0      129.0           2.0             16.0        20.0
#
#      away_runs  away_wickets  away_boundaries  \
# 987      178.0           5.0             25.0
# 918      179.0           5.0             21.0
# 957      129.0          10.0             15.0
# 871      135.0           7.0             17.0
# 848      128.0           8.0             14.0
#
#                                                                                                                                                                                                        highlights  \
# 987          Dhoni scripts narrow Chennai win. The Chennai Super Kings overcame two adverse situations, the first with the bat and then with the ball, to extend their unbeaten streak in the IPL to four matches
# 918                                                                                                                                                                                                           NaN
# 957                                                                                                                                                                                                           NaN
# 871              Robin Uthappa's blitz floors Chennai. Robin Uthappa's blitz helped his team recover from a shaky start, after which Bangalore's bowlers throttled Chennai to move to the top of the points table
# 848  Bangalore finish on top of table. Chris Gayle indulged himself after his bowlers restricted Chennai Super Kings to a below-par 128 to ensure Royal Challengers Bangalore will finish top of the points table
#
#                  home_key_batsman                home_key_bowler  \
# 987      Ross Taylor,Wasim Jaffer      Zaheer Khan,Praveen Kumar
# 918  Jacques Kallis,Robin Uthappa  Praveen Kumar,Kevin Pietersen
# 957       Ross Taylor,Virat Kohli     Anil Kumble,Jacques Kallis
# 871     Robin Uthappa,Virat Kohli        Vinay Kumar,Anil Kumble
# 848       Chris Gayle,Virat Kohli     Daniel Vettori,Zaheer Khan
#
#                                                                                                                                                                                                                 home_playx1  \
# 987               Bharat Chipli (BT),Wasim Jaffer (BT),Ross Taylor (BT),Jacques Kallis (AR),Mark Boucher (WK),Virat Kohli (BT),Rahul Dravid (BT),Praveen Kumar (BL),Zaheer Khan (BL),Balachandra Akhil (BL),Dale Steyn (BL)
# 918              Praveen Kumar (BL),Robin Uthappa (WK),Jacques Kallis (AR),Ross Taylor (BT),Kevin Pietersen (BT),Rahul Dravid (BT),Virat Kohli (BT),Rajesh Bishnoi (UKN),Vinay Kumar (BL),Dale Steyn (BL),Anil Kumble (UKN)
# 957     Robin Uthappa (BT),Jacques Kallis (AR),Rahul Dravid (BT),Ross Taylor (BT),Virat Kohli (BT),Mark Boucher (WK),Roelof van der Merwe (AR),Balachandra Akhil (BL),Praveen Kumar (BL),Vinay Kumar (BL),Anil Kumble (UKN)
# 871                   Manish Pandey (BT),Jacques Kallis (AR),Rahul Dravid (BT),Robin Uthappa (BT),Virat Kohli (BT),Eoin Morgan (BT),Mark Boucher (WK),Praveen Kumar (BL),Anil Kumble (UKN),Dale Steyn (BL),Vinay Kumar (BL)
# 848  AB de Villiers (WK),Chris Gayle (AR),Virat Kohli (BT),Saurabh Tiwary (BT),Mayank Agarwal (BT),Mohammad Kaif (BT),Luke Pomersbach (BT),Daniel Vettori (AR),Sreenath Aravind (BL),Abhimanyu Mithun (BL),Zaheer Khan (BL)
#
#                                                                                                                                                                                                                         away_playx1  \
# 987                    Parthiv Patel (BT),Matthew Hayden (BT),Michael Hussey (BT),Suresh Raina (BT),MS Dhoni (WK),Jacob Oram (AR),S Badrinath (BT),Albie Morkel (AR),Joginder Sharma (AR),Palani  Amarnath (UKN),Manpreet Gony (BL)
# 918       Parthiv Patel (BT),Matthew Hayden (BT),Suresh Raina (BT),MS Dhoni (WK),Andrew Flintoff (AR),Albie Morkel (AR),S Badrinath (BT),Joginder Sharma (AR),Lakshmipathy Balaji (BL),Manpreet Gony (BL),Muttiah Muralitharan (BL)
# 957                Murali Vijay (BT),Matthew Hayden (BT),Suresh Raina (BT),MS Dhoni (WK),Jacob Oram (AR),S Badrinath (BT),Albie Morkel (AR),Shadab Jakati (BL),Lakshmipathy Balaji (BL),Muttiah Muralitharan (BL),Sudeep Tyagi (BL)
# 871  Parthiv Patel (WK),Matthew Hayden (BT),George Bailey (BT),Suresh Raina (BT),Murali Vijay (BT),S Badrinath (BT),Albie Morkel (AR),Ravichandran Ashwin (AR),Lakshmipathy Balaji (BL),Muttiah Muralitharan (BL),Sudeep Tyagi (BL)
# 848                 Michael Hussey (BT),Murali Vijay (BT),Suresh Raina (BT),S Badrinath (BT),Wriddhiman Saha (BT),MS Dhoni (WK),Dwayne Bravo (AR),Albie Morkel (AR),Ravichandran Ashwin (AR),Shadab Jakati (BL),Doug Bollinger (BL)
#
#                  away_key_batsman                           away_key_bowler  \
# 987       MS Dhoni,Michael Hussey             Manpreet Gony,Joginder Sharma
# 918  Matthew Hayden,Parthiv Patel  Muttiah Muralitharan,Lakshmipathy Balaji
# 957       Matthew Hayden,MS Dhoni                   Albie Morkel,Jacob Oram
# 871    Matthew Hayden,S Badrinath         Muttiah Muralitharan,Albie Morkel
# 848      MS Dhoni,Wriddhiman Saha          Ravichandran Ashwin,Albie Morkel
#
#                                           match_days         umpire1  \
# 987      28 April 2008 - night match (20-over match)  Russell Tiffin
# 918  20 April 2009 - day/night match (20-over match)    Simon Taufel
# 957                      14 May 2009 (20-over match)    Daryl Harper
# 871      23 March 2010 - night match (20-over match)  Russell Tiffin
# 848    22 May 2011 - day/night match (20-over match)   Rudi Koertzen
#
#                umpire2          tv_umpire             referee  \
# 987     Billy Doctrove  Krishna Hariharan     Javagal Srinath
# 918      Brian Jerling     Russell Tiffin  Gundappa Viswanath
# 957     Billy Doctrove     Suresh Shastri       Dev Govindjee
# 871      Rudi Koertzen      Brian Jerling        Andy Pycroft
# 848  Krishna Hariharan   Kumar Dharmasena     Roshan Mahanama
#
#             reserve_umpire  output  run_rate  bowl_econ season_match  \
# 987                    NaN       0  8.505155   8.900000   15th match
# 918           Shaun George       0  5.723684   8.950000    5th match
# 957           Murray Brown       1  6.804124   6.649485          NaN
# 871  KN Ananthapadmanabhan       1  8.550000   6.750000   18th match
# 848                 Nandan       1  7.166667   6.400000   69th match
#
#     day_night_play  shifted_home_win  h2h_home_win_ratio_last_10  \
# 987              N               NaN                         NaN
# 918            D/N               0.0                    0.000000
# 957            NaN               0.0                    0.000000
# 871              N               1.0                    0.333333
# 848            D/N               1.0                    0.500000
#
#      shifted_runs  h2h_avg_runs_last_10
# 987           NaN                   NaN
# 918         165.0                165.00
# 957          87.0                126.00
# 871         132.0                128.00
# 848         171.0                138.75

# %%
def gen_ELO(df):
    df = df.sort_values('start_date')  # Ensure time order

    # Dictionary storing current Elo ratings for each team
    current_ratings = {}

    def get_rating(team):
        # Default to 1500 if the team isn't in our dict yet
        return current_ratings.get(team, 1500)

    K = 20
    updated_rows = []
    for idx, row in df.iterrows():
        teamA = row['home_team']
        teamB = row['away_team']
        S_A = row['output']  # 1 if A wins, 0 if B wins, 0.5 tie

        R_A = get_rating(teamA)
        R_B = get_rating(teamB)

        # Expected score for Team A
        E_A = 1 / (1 + 10 ** ((R_B - R_A) / 400))

        # Update both teams
        R_A_new = R_A + K * (S_A - E_A)
        R_B_new = R_B + K * ((1 - S_A) - (1 - E_A))

        # Store the new ratings
        current_ratings[teamA] = R_A_new
        current_ratings[teamB] = R_B_new

        # Optionally add to the row’s data
        row['elo_home_before'] = R_A
        row['elo_away_before'] = R_B
        row['elo_home_after'] = R_A_new
        row['elo_away_after'] = R_B_new
        row['elo_before'] = R_A - R_B
        updated_rows.append(row)

    # Create a new DataFrame with updated rating info
    df_updated = pd.DataFrame(updated_rows)
    return df_updated

# %%
mdf = gen_ELO(mdf)
# mdf[mdf.home_team == 'RCB']

# %%
def shift_and_roll_mean(df, group_col, value_col, new_col_name,
                        window=5, min_periods=1, fillna_val=0):
    """
    For the given 'value_col', do:
      1) Shift by 1 within each group.
      2) Rolling mean with the specified window.
      3) Create a new column with the result.
    """

    shifted = df.groupby(group_col)[value_col].shift(1)

    rolled = (
        shifted.groupby(df[group_col])
               .rolling(window=window, min_periods=min_periods)
               .mean()
    )
    df[new_col_name] = rolled.reset_index(level=0, drop=True)

    # Fill NaN for first matches
    df[new_col_name] = df[new_col_name].fillna(fillna_val)

    return df

# %%
def generate_new(my_df, team):
    my_df = my_df.sort_values(by=[
        team,
        'start_date'
    ])
    my_df = shift_and_roll_mean(my_df, team, 'home_runs', f'{team}_avg_runs_scored_last_5')
    my_df = shift_and_roll_mean(my_df, team, 'away_runs', f'{team}_avg_runs_conceded_last_5')
    my_df = shift_and_roll_mean(my_df, team, 'output', f'{team}_win_ratio_last_5')
    my_df = shift_and_roll_mean(my_df, team, 'run_rate', f'{team}_avg_run_rate_last_5')
    my_df = shift_and_roll_mean(my_df, team, 'bowl_econ', f'{team}_avg_bowl_econ_last_5')
    my_df = shift_and_roll_mean(my_df, team, 'home_boundaries', f'{team}_avg_boundaries_scored_last_5')
    my_df = shift_and_roll_mean(my_df, team, 'away_boundaries', f'{team}_avg_boundaries_conceded_last_5')
    return my_df

# %%
# Now shift+roll multiple columns
inter_df = generate_new(mdf, 'home_team')
# inter_df[inter_df.home_team == 'RCB']

# %%
proc_df = generate_new(inter_df, 'away_team')
# proc_df[proc_df.away_team == 'RCB']

# %% [markdown]
# #### cleanup columns

# %%
cols_to_remove = ['result', '1st_inning_score', '2nd_inning_score', 'home_score', 'away_score', 'home_runs', 'away_runs', 'home_wickets', 'away_wickets',
                  'pom', 'points', 'highlights', 'shifted_home_win', 'shifted_runs']

# %%
proc_df.drop(columns=cols_to_remove, axis=1, inplace=True)

# %%
# Secondary column removal
sec_cols_to_remove = ['id', 'description', 'name', 'venue_name', 'match_days', 'umpire1', 'umpire2', 'tv_umpire', 'referee', 'reserve_umpire']

# %%
proc_df.drop(columns=sec_cols_to_remove, axis=1, inplace=True)

# %%
# gen_df

# %%
proc_df.columns
# Out:
# Index(['season', 'short_name', 'home_team', 'away_team', 'toss_won',
#        'decision', 'winner', 'start_date', 'end_date', 'venue_id',
#        'home_captain', 'away_captain', 'super_over', 'home_overs',
#        'home_boundaries', 'away_overs', 'away_boundaries', 'home_key_batsman',
#        'home_key_bowler', 'home_playx1', 'away_playx1', 'away_key_batsman',
#        'away_key_bowler', 'output', 'run_rate', 'bowl_econ', 'season_match',
#        'day_night_play', 'h2h_home_win_ratio_last_10', 'h2h_avg_runs_last_10',
#        'elo_home_before', 'elo_away_before', 'elo_home_after',
#        'elo_away_after', 'elo_before', 'home_team_avg_runs_scored_last_5',
#        'home_team_avg_runs_conceded_last_5', 'home_team_win_ratio_last_5',
#        'home_team_avg_run_rate_last_5', 'home_team_avg_bowl_econ_last_5',
#        'home_team_avg_boundaries_scored_last_5',
#        'home_team_avg_boundaries_conceded_last_5',
#        'away_team_avg_runs_scored_last_5',
#        'away_team_avg_runs_conceded_last_5', 'away_team_win_ratio_last_5',
#        'away_team_avg_run_rate_last_5', 'away_team_avg_bowl_econ_last_5',
#        'away_team_avg_boundaries_scored_last_5',
#        'away_team_avg_boundaries_conceded_last_5'],
#       dtype='object')

# %%
# data leakage candidates 
ter_cols_to_remove = ['winner', 'super_over', 'home_overs', 'away_overs', 'home_boundaries', 'away_boundaries', 'elo_home_after', 'elo_away_after', 'elo_home_before', 'elo_away_before', 'run_rate', 'bowl_econ']
proc_df.drop(columns=ter_cols_to_remove, axis=1, inplace=True)

# %%
# other NLP fields (to be removed unless advanced analytics needed)
cat_cols_to_remove = ['short_name', 'start_date', 'end_date', 'home_captain', 'away_captain', 'home_key_batsman', 'home_key_bowler', 'home_playx1', 'away_playx1',
       'away_key_batsman', 'away_key_bowler']
proc_df.drop(columns=cat_cols_to_remove, axis=1, inplace=True)

# %%
# proc_df

# %%
# proc_df[(proc_df.home_team == 'RCB') | (proc_df.away_team == 'RCB')]

# %%
# proc_df[proc_df.away_team_avg_runs_scored_last_5 == 0.0]

# %%
proc_df.head()
# Out:
#       season home_team away_team toss_won    decision  venue_id  output  \
# 974   2008.0      KXIP       CSK      CSK   BAT FIRST     57991       0
# 987   2008.0       RCB       CSK      CSK   BAT FIRST     57897       0
# 996   2008.0        RR       CSK      CSK   BAT FIRST     58162       1
# 1000  2008.0        DC       CSK      CSK  BOWL FIRST     58040       0
# 1008  2008.0        MI       CSK       MI  BOWL FIRST     58324       1
#
#      season_match day_night_play  h2h_home_win_ratio_last_10  \
# 974     2nd match            D/N                         NaN
# 987    15th match              N                         NaN
# 996    24th match              N                         NaN
# 1000   28th match            D/N                         NaN
# 1008   36th match              N                         NaN
#
#       h2h_avg_runs_last_10  elo_before  home_team_avg_runs_scored_last_5  \
# 974                    NaN    0.000000                              0.00
# 987                    NaN  -38.873861                            108.50
# 996                    NaN    0.863448                            182.00
# 1000                   NaN   10.633111                            161.50
# 1008                   NaN  -31.885898                            146.25
#
#       home_team_avg_runs_conceded_last_5  home_team_win_ratio_last_5  \
# 974                                 0.00                         0.0
# 987                               180.00                         0.0
# 996                               158.50                         1.0
# 1000                              155.00                         1.0
# 1008                              139.25                         0.5
#
#       home_team_avg_run_rate_last_5  home_team_avg_bowl_econ_last_5  \
# 974                        0.000000                        0.000000
# 987                        6.090232                        9.585088
# 996                        9.540884                        8.102880
# 1000                       9.145861                        7.750000
# 1008                       7.734354                        8.755145
#
#       home_team_avg_boundaries_scored_last_5  \
# 974                                      0.0
# 987                                     12.5
# 996                                     25.5
# 1000                                    22.5
# 1008                                    18.5
#
#       home_team_avg_boundaries_conceded_last_5  \
# 974                                        0.0
# 987                                       26.5
# 996                                       19.5
# 1000                                      20.0
# 1008                                      17.5
#
#       away_team_avg_runs_scored_last_5  away_team_avg_runs_conceded_last_5  \
# 974                           0.000000                            0.000000
# 987                         207.000000                          240.000000
# 996                         186.000000                          209.000000
# 1000                        160.666667                          175.666667
# 1008                        167.250000                          178.750000
#
#       away_team_win_ratio_last_5  away_team_avg_run_rate_last_5  \
# 974                     0.000000                       0.000000
# 987                     0.000000                      10.350000
# 996                     0.000000                       9.427577
# 1000                    0.333333                       8.867211
# 1008                    0.250000                       8.987908
#
#       away_team_avg_bowl_econ_last_5  away_team_avg_boundaries_scored_last_5  \
# 974                         0.000000                                0.000000
# 987                        12.000000                               27.000000
# 996                        10.450000                               23.000000
# 1000                        8.878947                               19.333333
# 1008                        9.009211                               20.750000
#
#       away_team_avg_boundaries_conceded_last_5
# 974                                   0.000000
# 987                                  36.000000
# 996                                  30.500000
# 1000                                 24.666667
# 1008                                 24.750000

# %%
proc_df.decision.value_counts()
# Out:
# decision
# BOWL FIRST    650
# BAT FIRST     372
# no toss         7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
for team in proc_df.home_team.unique():
    print(f'{team} ELO: {proc_df[proc_df.home_team == team].elo_before.mean()}')
# Out:
# KXIP ELO: -24.788791472966157
# RCB ELO: -21.580147716267938
# RR ELO: -2.903116852894499
# DC ELO: -40.36751905113323
# MI ELO: 41.63284986000127
# KKR ELO: 8.739091340916374
# SRH ELO: -19.581267639961315
# Kochi ELO: -0.050340894893062274
# PWI ELO: -66.94604532068882
# PBKS ELO: -20.284203216073557
# LSG ELO: 6.596440079350728
# GT ELO: 47.18265349603509
# CSK ELO: 49.814856887387755
# GL ELO: 6.415188038883798
# RPS ELO: -31.12731287246587

# %%
mean_elos = proc_df.groupby('home_team')['elo_before'].mean().sort_values().reset_index()
mean_elos
# Out:
#    home_team  elo_before
# 0        PWI  -66.946045
# 1         DC  -40.367519
# 2        RPS  -31.127313
# 3       KXIP  -24.788791
# 4        RCB  -21.580148
# 5       PBKS  -20.284203
# 6        SRH  -19.581268
# 7         RR   -2.903117
# 8      Kochi   -0.050341
# 9         GL    6.415188
# 10       LSG    6.596440
# 11       KKR    8.739091
# 12        MI   41.632850
# 13        GT   47.182653
# 14       CSK   49.814857

# %%
plt.bar(mean_elos.home_team, mean_elos.elo_before)
# plt.ylim(1200, 1800)
plt.xticks(rotation=45)
plt.show()

# %%
proc_df.head()
# Out:
#       season home_team away_team toss_won    decision  venue_id  output  \
# 974   2008.0      KXIP       CSK      CSK   BAT FIRST     57991       0
# 987   2008.0       RCB       CSK      CSK   BAT FIRST     57897       0
# 996   2008.0        RR       CSK      CSK   BAT FIRST     58162       1
# 1000  2008.0        DC       CSK      CSK  BOWL FIRST     58040       0
# 1008  2008.0        MI       CSK       MI  BOWL FIRST     58324       1
#
#      season_match day_night_play  h2h_home_win_ratio_last_10  \
# 974     2nd match            D/N                         NaN
# 987    15th match              N                         NaN
# 996    24th match              N                         NaN
# 1000   28th match            D/N                         NaN
# 1008   36th match              N                         NaN
#
#       h2h_avg_runs_last_10  elo_before  home_team_avg_runs_scored_last_5  \
# 974                    NaN    0.000000                              0.00
# 987                    NaN  -38.873861                            108.50
# 996                    NaN    0.863448                            182.00
# 1000                   NaN   10.633111                            161.50
# 1008                   NaN  -31.885898                            146.25
#
#       home_team_avg_runs_conceded_last_5  home_team_win_ratio_last_5  \
# 974                                 0.00                         0.0
# 987                               180.00                         0.0
# 996                               158.50                         1.0
# 1000                              155.00                         1.0
# 1008                              139.25                         0.5
#
#       home_team_avg_run_rate_last_5  home_team_avg_bowl_econ_last_5  \
# 974                        0.000000                        0.000000
# 987                        6.090232                        9.585088
# 996                        9.540884                        8.102880
# 1000                       9.145861                        7.750000
# 1008                       7.734354                        8.755145
#
#       home_team_avg_boundaries_scored_last_5  \
# 974                                      0.0
# 987                                     12.5
# 996                                     25.5
# 1000                                    22.5
# 1008                                    18.5
#
#       home_team_avg_boundaries_conceded_last_5  \
# 974                                        0.0
# 987                                       26.5
# 996                                       19.5
# 1000                                      20.0
# 1008                                      17.5
#
#       away_team_avg_runs_scored_last_5  away_team_avg_runs_conceded_last_5  \
# 974                           0.000000                            0.000000
# 987                         207.000000                          240.000000
# 996                         186.000000                          209.000000
# 1000                        160.666667                          175.666667
# 1008                        167.250000                          178.750000
#
#       away_team_win_ratio_last_5  away_team_avg_run_rate_last_5  \
# 974                     0.000000                       0.000000
# 987                     0.000000                      10.350000
# 996                     0.000000                       9.427577
# 1000                    0.333333                       8.867211
# 1008                    0.250000                       8.987908
#
#       away_team_avg_bowl_econ_last_5  away_team_avg_boundaries_scored_last_5  \
# 974                         0.000000                                0.000000
# 987                        12.000000                               27.000000
# 996                        10.450000                               23.000000
# 1000                        8.878947                               19.333333
# 1008                        9.009211                               20.750000
#
#       away_team_avg_boundaries_conceded_last_5
# 974                                   0.000000
# 987                                  36.000000
# 996                                  30.500000
# 1000                                 24.666667
# 1008                                 24.750000

# %%
proc_df.season.unique()
# Out:
# array([2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015., 2018.,
#        2019., 2020., 2021., 2022., 2023.,   nan, 2016., 2017.])

# %% [markdown]
# ### Handle N/A s

# %%
proc_df.isna().sum()
# Out:
# season                                        3
# home_team                                     0
# away_team                                     0
# toss_won                                      3
# decision                                      3
# venue_id                                      0
# output                                        0
# season_match                                 37
# day_night_play                               37
# h2h_home_win_ratio_last_10                  159
# h2h_avg_runs_last_10                        159
# elo_before                                    0
# home_team_avg_runs_scored_last_5              0
# home_team_avg_runs_conceded_last_5            0
# home_team_win_ratio_last_5                    0
# home_team_avg_run_rate_last_5                 0
# home_team_avg_bowl_econ_last_5                0
# home_team_avg_boundaries_scored_last_5        0
# home_team_avg_boundaries_conceded_last_5      0
# away_team_avg_runs_scored_last_5              0
# away_team_avg_runs_conceded_last_5            0
# away_team_win_ratio_last_5                    0
# away_team_avg_run_rate_last_5                 0
# away_team_avg_bowl_econ_last_5                0
# away_team_avg_boundaries_scored_last_5        0
# away_team_avg_boundaries_conceded_last_5      0
# dtype: int64

# %%
season_min = proc_df.season.min()
proc_df['season'] = proc_df.season.fillna(season_min)

# %%
proc_df['toss_won'] = proc_df.toss_won.fillna('')
proc_df['decision'] = proc_df.decision.fillna('')
proc_df['day_night_play'] = proc_df.day_night_play.fillna('')
proc_df['season_match'] = proc_df.season_match.fillna('')

# %%
for c in ['h2h_home_win_ratio_last_10', 'h2h_avg_runs_last_10']:
    mean_c = proc_df[c].mean()
    proc_df[c] = proc_df[c].fillna(mean_c)

# %%
proc_df.isna().sum()
# Out:
# season                                      0
# home_team                                   0
# away_team                                   0
# toss_won                                    0
# decision                                    0
# venue_id                                    0
# output                                      0
# season_match                                0
# day_night_play                              0
# h2h_home_win_ratio_last_10                  0
# h2h_avg_runs_last_10                        0
# elo_before                                  0
# home_team_avg_runs_scored_last_5            0
# home_team_avg_runs_conceded_last_5          0
# home_team_win_ratio_last_5                  0
# home_team_avg_run_rate_last_5               0
# home_team_avg_bowl_econ_last_5              0
# home_team_avg_boundaries_scored_last_5      0
# home_team_avg_boundaries_conceded_last_5    0
# away_team_avg_runs_scored_last_5            0
# away_team_avg_runs_conceded_last_5          0
# away_team_win_ratio_last_5                  0
# away_team_avg_run_rate_last_5               0
# away_team_avg_bowl_econ_last_5              0
# away_team_avg_boundaries_scored_last_5      0
# away_team_avg_boundaries_conceded_last_5    0
# dtype: int64

# %%
cat_cols = [col  for col in proc_df.columns if proc_df[col].dtype == object]
num_cols = list(set(proc_df.columns) - set(cat_cols))
for col in cat_cols:
    proc_df[col] = (
        proc_df[col]
        .str.lower()
        .str.strip()
        .str.replace(r'\s+', '_', regex=True)
    )

# %% [markdown]
# ### Split / Shuffle Data for validation and testing.

# %%
from sklearn.model_selection import train_test_split

# %%
# Since it needs to be a time aware split, shuffle=False .. which results in past matches only for training and future matches for predicting.
df_full_train, df_test = train_test_split(proc_df, test_size=.2, shuffle=False, random_state=21)
df_train, df_val = train_test_split(df_full_train, test_size=20/80, shuffle=False, random_state=21)
len(df_train),  len(df_val), len(df_test)
# Out:
# (618, 207, 207)

# %%
df_train.head()
# Out:
#       season home_team away_team toss_won    decision  venue_id  output  \
# 974   2008.0      kxip       csk      csk   bat_first     57991       0
# 987   2008.0       rcb       csk      csk   bat_first     57897       0
# 996   2008.0        rr       csk      csk   bat_first     58162       1
# 1000  2008.0        dc       csk      csk  bowl_first     58040       0
# 1008  2008.0        mi       csk       mi  bowl_first     58324       1
#
#      season_match day_night_play  h2h_home_win_ratio_last_10  \
# 974     2nd_match            d/n                    0.536102
# 987    15th_match              n                    0.536102
# 996    24th_match              n                    0.536102
# 1000   28th_match            d/n                    0.536102
# 1008   36th_match              n                    0.536102
#
#       h2h_avg_runs_last_10  elo_before  home_team_avg_runs_scored_last_5  \
# 974              154.45671    0.000000                              0.00
# 987              154.45671  -38.873861                            108.50
# 996              154.45671    0.863448                            182.00
# 1000             154.45671   10.633111                            161.50
# 1008             154.45671  -31.885898                            146.25
#
#       home_team_avg_runs_conceded_last_5  home_team_win_ratio_last_5  \
# 974                                 0.00                         0.0
# 987                               180.00                         0.0
# 996                               158.50                         1.0
# 1000                              155.00                         1.0
# 1008                              139.25                         0.5
#
#       home_team_avg_run_rate_last_5  home_team_avg_bowl_econ_last_5  \
# 974                        0.000000                        0.000000
# 987                        6.090232                        9.585088
# 996                        9.540884                        8.102880
# 1000                       9.145861                        7.750000
# 1008                       7.734354                        8.755145
#
#       home_team_avg_boundaries_scored_last_5  \
# 974                                      0.0
# 987                                     12.5
# 996                                     25.5
# 1000                                    22.5
# 1008                                    18.5
#
#       home_team_avg_boundaries_conceded_last_5  \
# 974                                        0.0
# 987                                       26.5
# 996                                       19.5
# 1000                                      20.0
# 1008                                      17.5
#
#       away_team_avg_runs_scored_last_5  away_team_avg_runs_conceded_last_5  \
# 974                           0.000000                            0.000000
# 987                         207.000000                          240.000000
# 996                         186.000000                          209.000000
# 1000                        160.666667                          175.666667
# 1008                        167.250000                          178.750000
#
#       away_team_win_ratio_last_5  away_team_avg_run_rate_last_5  \
# 974                     0.000000                       0.000000
# 987                     0.000000                      10.350000
# 996                     0.000000                       9.427577
# 1000                    0.333333                       8.867211
# 1008                    0.250000                       8.987908
#
#       away_team_avg_bowl_econ_last_5  away_team_avg_boundaries_scored_last_5  \
# 974                         0.000000                                0.000000
# 987                        12.000000                               27.000000
# 996                        10.450000                               23.000000
# 1000                        8.878947                               19.333333
# 1008                        9.009211                               20.750000
#
#       away_team_avg_boundaries_conceded_last_5
# 974                                   0.000000
# 987                                  36.000000
# 996                                  30.500000
# 1000                                 24.666667
# 1008                                 24.750000

# %%
y_train = df_train.pop('output')
y_val = df_val.pop('output')
y_test = df_test.pop('output')
y_train.head()
# Out:
# 974     0
# 987     0
# 996     1
# 1000    0
# 1008    1
# Name: output, dtype: int64

# %%
df_full_train.dtypes
num_cols = list(set(df_train.columns) - set(cat_cols))

# %%
num_cols
# Out:
# ['away_team_win_ratio_last_5',
#  'home_team_avg_runs_scored_last_5',
#  'home_team_avg_run_rate_last_5',
#  'season',
#  'away_team_avg_boundaries_scored_last_5',
#  'home_team_avg_boundaries_scored_last_5',
#  'home_team_avg_bowl_econ_last_5',
#  'h2h_home_win_ratio_last_10',
#  'away_team_avg_run_rate_last_5',
#  'home_team_avg_runs_conceded_last_5',
#  'home_team_win_ratio_last_5',
#  'home_team_avg_boundaries_conceded_last_5',
#  'elo_before',
#  'venue_id',
#  'away_team_avg_bowl_econ_last_5',
#  'away_team_avg_boundaries_conceded_last_5',
#  'away_team_avg_runs_conceded_last_5',
#  'away_team_avg_runs_scored_last_5',
#  'h2h_avg_runs_last_10']

# %%
cat_cols
# Out:
# ['home_team',
#  'away_team',
#  'toss_won',
#  'decision',
#  'season_match',
#  'day_night_play']

# %%
df_full_train.home_team.value_counts()
# Out:
# home_team
# srh      110
# dc        98
# rcb       97
# csk       96
# mi        92
# kkr       86
# rr        84
# kxip      73
# pwi       18
# pbks      15
# lsg       14
# gt        13
# gl        12
# rps       12
# kochi      5
# Name: count, dtype: int64

# %%
df_full_train.decision.value_counts()
# Out:
# decision
# bowl_first    530
# bat_first     289
#                 3
# no_toss         3
# Name: count, dtype: int64

# %%
# Home team win rate

home_team_win_rate = df_full_train.output.mean()
home_team_win_rate
# Out:
# 0.5163636363636364

# %%
# Home team win rate w.r.t toss decision
bowl_first_wins = df_full_train[df_full_train.decision == 'BOWL FIRST'].output.mean()
bat_first_wins = df_full_train[df_full_train.decision == 'BAT FIRST'].output.mean()

bowl_first_wins, bat_first_wins
# Out:
# (nan, nan)

# %%
# Home team win rate w.r.t toss wins  
df_full_train[df_full_train.toss_won == df_full_train.home_team].output.mean()
# Out:
# 0.5358024691358024

# %%
# Home team win rate w.r.t toss decision  
bowl_first_wins = df_full_train[df_full_train.decision == 'BOWL FIRST'].output.mean()
bat_first_wins = df_full_train[df_full_train.decision == 'BAT FIRST'].output.mean()

bowl_first_wins, bat_first_wins
# Out:
# (nan, nan)

# %%
from IPython.display import display

for c in cat_cols:
    print(c)
    df_group = df_full_train.groupby(c).output.agg(['mean', 'count'])
    df_group['diff'] = home_team_win_rate - df_group['mean']
    df_group['risk'] = df_group['mean'] / home_team_win_rate
    display(df_group)
    print()
    print()
# Out:
# home_team
#                mean  count      diff      risk
# home_team
# csk        0.625000     96 -0.108636  1.210387
# dc         0.489796     98  0.026568  0.948548
# gl         0.416667     12  0.099697  0.806925
# gt         0.615385     13 -0.099021  1.191766
# kkr        0.488372     86  0.027992  0.945791
# kochi      0.400000      5  0.116364  0.774648
# kxip       0.506849     73  0.009514  0.981574
# lsg        0.428571     14  0.087792  0.829980
# mi         0.576087     92 -0.059723  1.115661
# pbks       0.333333     15  0.183030  0.645540
# pwi        0.277778     18  0.238586  0.537950
# rcb        0.505155     97  0.011209  0.978292
# rps        0.500000     12  0.016364  0.968310
# rr         0.583333     84 -0.066970  1.129695
# srh        0.463636    110  0.052727  0.897887
# away_team
#                mean  count      diff      risk
# away_team
# csk        0.470588    102  0.045775  0.911350
# dc         0.608696    115 -0.092332  1.178812
# gl         0.466667     15  0.049697  0.903756
# gt         0.266667     15  0.249697  0.516432
# kkr        0.528000    125 -0.011636  1.022535
# kochi      0.571429      7 -0.055065  1.106640
# kxip       0.577320     97 -0.060956  1.118048
# lsg        0.285714     14  0.230649  0.553320
# mi         0.449612    129  0.066751  0.870728
# pbks       0.363636     22  0.152727  0.704225
# pwi        0.695652     23 -0.179289  1.347214
# rcb        0.533898    118 -0.017535  1.033958
# rps        0.500000     16  0.016364  0.968310
# rr         0.518519     27 -0.002155  1.004173
# toss_won
#               mean  count      diff      risk
# toss_won
#           0.333333      3  0.183030  0.645540
# csk       0.542857    105 -0.026494  1.051308
# dc        0.557522    113 -0.041158  1.079708
# gl        0.266667     15  0.249697  0.516432
# gt        0.352941     17  0.163422  0.683513
# kkr       0.514019    107  0.002345  0.995459
# kochi     0.500000      6  0.016364  0.968310
# kxip      0.552941     85 -0.036578  1.070837
# lsg       0.500000     10  0.016364  0.968310
# mi        0.530435    115 -0.014071  1.027250
# no_toss   0.000000      3  0.516364  0.000000
# pwi       0.611111     18 -0.094747  1.183490
# rcb       0.528846    104 -0.012483  1.024174
# rps       0.583333     12 -0.066970  1.129695
# rr        0.557692     52 -0.041329  1.080038
# srh       0.366667     60  0.149697  0.710094
# decision
#                 mean  count      diff      risk
# decision
#             0.333333      3  0.183030  0.645540
# bat_first   0.543253    289 -0.026889  1.052074
# bowl_first  0.505660    530  0.010703  0.979272
# no_toss     0.000000      3  0.516364  0.000000
# season_match
#                                                       mean  count      diff  \
# season_match
#                                                   0.515152     33  0.001212
# 10th_match                                        0.692308     13 -0.175944
# 11th_match                                        0.538462     13 -0.022098
# 12th_match                                        0.363636     11  0.152727
# 12th_match,_pepsi_indian_premier_league_at_dubai  1.000000      1 -0.483636
# ...                                                    ...    ...       ...
# elimination_final                                 1.000000      2 -0.483636
# eliminator                                        0.000000      6  0.516364
# final                                             0.384615     13  0.131748
# qualifier_1                                       0.500000     10  0.016364
# qualifier_2                                       0.714286      7 -0.197922
#
#                                                       risk
# season_match
#                                                   0.997653
# 10th_match                                        1.340737
# 11th_match                                        1.042795
# 12th_match                                        0.704225
# 12th_match,_pepsi_indian_premier_league_at_dubai  1.936620
# ...                                                    ...
# elimination_final                                 1.936620
# eliminator                                        0.000000
# final                                             0.744854
# qualifier_1                                       0.968310
# qualifier_2                                       1.383300
#
# [90 rows x 4 columns]
# day_night_play
#                     mean  count      diff      risk
# day_night_play
#                 0.515152     33  0.001212  0.997653
# d/n             0.580189    212 -0.063825  1.123605
# dsc             0.400000      5  0.116364  0.774648
# n               0.493913    575  0.022451  0.956522

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(df_full_train.toss_won, df_full_train.output)
# Out:
# 0.011412760216100284

# %%
def mi_score_against_churn(series_col):
    return mutual_info_score(series_col, df_full_train.output)

# %%
mi_scores = df_full_train[cat_cols].apply(mi_score_against_churn)
mi_scores
# Out:
# home_team         0.010461
# away_team         0.012788
# toss_won          0.011413
# decision          0.003544
# season_match      0.070667
# day_night_play    0.002975
# dtype: float64

# %% [markdown]
# ### Correlation coefficient for numeric columns

# %%
corr_scores = df_full_train[num_cols].corrwith(df_full_train.output)
corr_scores.sort_values()
# Out:
# venue_id                                   -0.084251
# season                                     -0.041367
# away_team_avg_boundaries_conceded_last_5   -0.032768
# home_team_avg_boundaries_conceded_last_5   -0.029273
# away_team_avg_runs_conceded_last_5         -0.024797
# home_team_avg_bowl_econ_last_5             -0.022727
# away_team_avg_boundaries_scored_last_5     -0.022388
# away_team_avg_run_rate_last_5              -0.017706
# home_team_avg_runs_conceded_last_5         -0.017391
# away_team_win_ratio_last_5                 -0.013334
# away_team_avg_bowl_econ_last_5             -0.005234
# home_team_avg_run_rate_last_5              -0.004885
# away_team_avg_runs_scored_last_5           -0.003948
# home_team_avg_boundaries_scored_last_5      0.012656
# h2h_home_win_ratio_last_10                  0.015984
# home_team_avg_runs_scored_last_5            0.018537
# home_team_win_ratio_last_5                  0.024152
# h2h_avg_runs_last_10                        0.045376
# elo_before                                  0.053772
# dtype: float64

# %%
##  Train Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler
import category_encoders as ce

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.model_selection import KFold
from tqdm.auto import tqdm

# %%
# train_dicts = df_train.to_dict(orient='records')
# val_dicts = df_val.to_dict(orient='records')

# dv = DictVectorizer(sparse=False)

# X_train = dv.fit_transform(train_dicts)
# X_val = dv.transform(val_dicts)

# X_train.shape, X_val.shape

# %%
cat_cols
# Out:
# ['home_team',
#  'away_team',
#  'toss_won',
#  'decision',
#  'season_match',
#  'day_night_play']

# %%
num_cols
# Out:
# ['away_team_win_ratio_last_5',
#  'home_team_avg_runs_scored_last_5',
#  'home_team_avg_run_rate_last_5',
#  'season',
#  'away_team_avg_boundaries_scored_last_5',
#  'home_team_avg_boundaries_scored_last_5',
#  'home_team_avg_bowl_econ_last_5',
#  'h2h_home_win_ratio_last_10',
#  'away_team_avg_run_rate_last_5',
#  'home_team_avg_runs_conceded_last_5',
#  'home_team_win_ratio_last_5',
#  'home_team_avg_boundaries_conceded_last_5',
#  'elo_before',
#  'venue_id',
#  'away_team_avg_bowl_econ_last_5',
#  'away_team_avg_boundaries_conceded_last_5',
#  'away_team_avg_runs_conceded_last_5',
#  'away_team_avg_runs_scored_last_5',
#  'h2h_avg_runs_last_10']

# %%
# List of features for processing
categorical_features_small = ["day_night_play", "decision"]
high_cardinality_features = [
    'home_team',
    'away_team',
    'toss_won',
    'season_match'
 ]


# Target Encoding for High Cardinality Features
target_enc = ce.TargetEncoder(cols=high_cardinality_features)
df_train_encoded = target_enc.fit_transform(df_train, y_train)
df_val_encoded = target_enc.transform(df_val)

df_train = df_train_encoded.reset_index(drop=True)
df_val = df_val_encoded.reset_index(drop=True)

# %%
# Create Pipelines for Numerical and Categorical Features

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),    # Fill missing values with mean
    ('scaler', StandardScaler())                    # Standardize numerical values
])

# Categorical Transformer for One-Hot Encoding (for low cardinality categorical features)
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Column Transformer to apply transformations to different features
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, num_cols),
        ('cat', categorical_transformer, categorical_features_small)
    ],
    remainder='drop'  # Drop any columns not specified
)

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(random_state=21, max_iter=1000))
])

model.fit(df_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['away_team_win_ratio_last_5',
#                                                    'home_team_avg_runs_scored_last_5',
#                                                    'home_team_avg_run_rate_last_5',
#                                                    'season',
#                                                    'away_team_avg_boundaries_scored_last_5',
#                                                    'home_team_avg_boundaries_scored_last_5',
#                                                    'home_team_avg_bo...
#                                                    'elo_before', 'venue_id',
#                                                    'away_team_avg_bowl_econ_last_5',
#                                                    'away_team_avg_boundaries_conceded_last_5',
#                                                    'away_team_avg_runs_conceded_last_5',
#                                                    'away_team_avg_runs_scored_last_5',
#                                                    'h2h_avg_runs_last_10']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['day_night_play',
#                                                    'decision'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=21))])

# %%
df_train.head()
# Out:
#    season  home_team  away_team  toss_won    decision  venue_id  season_match  \
# 0  2008.0   0.463488   0.470599  0.516126   bat_first     57991      0.547469
# 1  2008.0   0.488403   0.470599  0.516126   bat_first     57897      0.494914
# 2  2008.0   0.623621   0.470599  0.516126   bat_first     58162      0.535175
# 3  2008.0   0.507277   0.470599  0.516126  bowl_first     58040      0.535175
# 4  2008.0   0.601945   0.470599  0.521271  bowl_first     58324      0.547469
#
#   day_night_play  h2h_home_win_ratio_last_10  h2h_avg_runs_last_10  \
# 0            d/n                    0.536102             154.45671
# 1              n                    0.536102             154.45671
# 2              n                    0.536102             154.45671
# 3            d/n                    0.536102             154.45671
# 4              n                    0.536102             154.45671
#
#    elo_before  home_team_avg_runs_scored_last_5  \
# 0    0.000000                              0.00
# 1  -38.873861                            108.50
# 2    0.863448                            182.00
# 3   10.633111                            161.50
# 4  -31.885898                            146.25
#
#    home_team_avg_runs_conceded_last_5  home_team_win_ratio_last_5  \
# 0                                0.00                         0.0
# 1                              180.00                         0.0
# 2                              158.50                         1.0
# 3                              155.00                         1.0
# 4                              139.25                         0.5
#
#    home_team_avg_run_rate_last_5  home_team_avg_bowl_econ_last_5  \
# 0                       0.000000                        0.000000
# 1                       6.090232                        9.585088
# 2                       9.540884                        8.102880
# 3                       9.145861                        7.750000
# 4                       7.734354                        8.755145
#
#    home_team_avg_boundaries_scored_last_5  \
# 0                                     0.0
# 1                                    12.5
# 2                                    25.5
# 3                                    22.5
# 4                                    18.5
#
#    home_team_avg_boundaries_conceded_last_5  away_team_avg_runs_scored_last_5  \
# 0                                       0.0                          0.000000
# 1                                      26.5                        207.000000
# 2                                      19.5                        186.000000
# 3                                      20.0                        160.666667
# 4                                      17.5                        167.250000
#
#    away_team_avg_runs_conceded_last_5  away_team_win_ratio_last_5  \
# 0                            0.000000                    0.000000
# 1                          240.000000                    0.000000
# 2                          209.000000                    0.000000
# 3                          175.666667                    0.333333
# 4                          178.750000                    0.250000
#
#    away_team_avg_run_rate_last_5  away_team_avg_bowl_econ_last_5  \
# 0                       0.000000                        0.000000
# 1                      10.350000                       12.000000
# 2                       9.427577                       10.450000
# 3                       8.867211                        8.878947
# 4                       8.987908                        9.009211
#
#    away_team_avg_boundaries_scored_last_5  \
# 0                                0.000000
# 1                               27.000000
# 2                               23.000000
# 3                               19.333333
# 4                               20.750000
#
#    away_team_avg_boundaries_conceded_last_5
# 0                                  0.000000
# 1                                 36.000000
# 2                                 30.500000
# 3                                 24.666667
# 4                                 24.750000

# %%
for c in [0.1, 0.25, 0.4, 0.5, 0.75, 1, 2]:
    model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', LogisticRegression(random_state=21, C=c, max_iter=1000))
    ])  

    model.fit(df_train, y_train)
    y_pred = model.predict(df_val)
    print(f"C={c} Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")
# Out:
# C=0.1 Accuracy: 0.5942028985507246 , ROC: 0.5822399250234301
# C=0.25 Accuracy: 0.6183574879227053 , ROC: 0.6074039362699156
# C=0.4 Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279
# C=0.5 Accuracy: 0.6328502415458938 , ROC: 0.6216494845360825
# C=0.75 Accuracy: 0.6280193236714976 , ROC: 0.6164948453608248
# C=1 Accuracy: 0.6328502415458938 , ROC: 0.6216494845360825
# C=2 Accuracy: 0.6376811594202898 , ROC: 0.6274133083411434

# %%
for i in [10, 100, 1000, 5000, 10000, 20000]:
    model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', LogisticRegression(random_state=21, C=0.4, max_iter=i))
    ])  

    model.fit(df_train, y_train)
    y_pred = model.predict(df_val)
    print(f"max iter={i} Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")
# Out:
# max iter=10 Accuracy: 0.6135265700483091 , ROC: 0.6034676663542643
# max iter=100 Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279
# max iter=1000 Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279
# max iter=5000 Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279
# max iter=10000 Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279
# max iter=20000 Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279
# /Users/anup.sethuram/.local/share/virtualenvs/ipl_note-CxxBWMJC/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(random_state=21, C=0.4, max_iter=1000, solver='liblinear', penalty='l1'))
])  

model.fit(df_train, y_train)
y_pred = model.predict(df_val)
print(f"C={0.4} and L1 penalty with liblinear, Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")
# Out:
# C=0.4 and L1 penalty with liblinear, Accuracy: 0.5748792270531401 , ROC: 0.5616213683223992

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(random_state=21, C=0.4, max_iter=1000, penalty='l2'))
])  

model.fit(df_train, y_train)
y_pred = model.predict(df_val)
print(f"C={0.4} and L2 penalty, Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")
# Out:
# C=0.4 and L2 penalty, Accuracy: 0.6280193236714976 , ROC: 0.6171040299906279

# %%
## Cross validation
y_full_train = df_full_train.pop('output')
    

kfold = KFold(n_splits=10, shuffle=True, random_state=1)
scores = []

for train_idx, val_idx in tqdm(kfold.split(df_full_train)):

    df_train = df_full_train.iloc[train_idx]
    df_val = df_full_train.iloc[val_idx]

    y_train = y_full_train.iloc[train_idx].values
    y_val = y_full_train.iloc[val_idx].values

    model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', LogisticRegression(random_state=21, C=0.4, max_iter=1000, penalty='l2'))
    ])  

    model.fit(df_train, y_train)
    y_pred = model.predict(df_val)
    print(f"C={0.4} and L2 penalty, Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")

    auc = roc_auc_score(y_val, y_pred)
    scores.append(auc)
# Out:
# 0it [00:00, ?it/s]
# C=0.4 and L2 penalty, Accuracy: 0.5060240963855421 , ROC: 0.49766899766899764
# 4it [00:00, 36.85it/s]
# C=0.4 and L2 penalty, Accuracy: 0.39759036144578314 , ROC: 0.3989547038327526
# C=0.4 and L2 penalty, Accuracy: 0.6265060240963856 , ROC: 0.6289198606271776
# C=0.4 and L2 penalty, Accuracy: 0.5180722891566265 , ROC: 0.5174418604651163
# C=0.4 and L2 penalty, Accuracy: 0.46987951807228917 , ROC: 0.47943595769682723
# C=0.4 and L2 penalty, Accuracy: 0.4146341463414634 , ROC: 0.41485507246376807
# 8it [00:00, 37.98it/s]
# C=0.4 and L2 penalty, Accuracy: 0.5975609756097561 , ROC: 0.591025641025641
# C=0.4 and L2 penalty, Accuracy: 0.524390243902439 , ROC: 0.5377241805813234
# C=0.4 and L2 penalty, Accuracy: 0.47560975609756095 , ROC: 0.4722222222222222
# 10it [00:00, 37.93it/s]
# C=0.4 and L2 penalty, Accuracy: 0.47560975609756095 , ROC: 0.47376267143709005

# %%
# Cross val doesn't make too much sense in a time ordered pred model..

# %%
df_train.head()
# Out:
#       season home_team away_team toss_won    decision  venue_id season_match  \
# 974   2008.0      kxip       csk      csk   bat_first     57991    2nd_match
# 987   2008.0       rcb       csk      csk   bat_first     57897   15th_match
# 996   2008.0        rr       csk      csk   bat_first     58162   24th_match
# 1000  2008.0        dc       csk      csk  bowl_first     58040   28th_match
# 1008  2008.0        mi       csk       mi  bowl_first     58324   36th_match
#
#      day_night_play  h2h_home_win_ratio_last_10  h2h_avg_runs_last_10  \
# 974             d/n                    0.536102             154.45671
# 987               n                    0.536102             154.45671
# 996               n                    0.536102             154.45671
# 1000            d/n                    0.536102             154.45671
# 1008              n                    0.536102             154.45671
#
#       elo_before  home_team_avg_runs_scored_last_5  \
# 974     0.000000                              0.00
# 987   -38.873861                            108.50
# 996     0.863448                            182.00
# 1000   10.633111                            161.50
# 1008  -31.885898                            146.25
#
#       home_team_avg_runs_conceded_last_5  home_team_win_ratio_last_5  \
# 974                                 0.00                         0.0
# 987                               180.00                         0.0
# 996                               158.50                         1.0
# 1000                              155.00                         1.0
# 1008                              139.25                         0.5
#
#       home_team_avg_run_rate_last_5  home_team_avg_bowl_econ_last_5  \
# 974                        0.000000                        0.000000
# 987                        6.090232                        9.585088
# 996                        9.540884                        8.102880
# 1000                       9.145861                        7.750000
# 1008                       7.734354                        8.755145
#
#       home_team_avg_boundaries_scored_last_5  \
# 974                                      0.0
# 987                                     12.5
# 996                                     25.5
# 1000                                    22.5
# 1008                                    18.5
#
#       home_team_avg_boundaries_conceded_last_5  \
# 974                                        0.0
# 987                                       26.5
# 996                                       19.5
# 1000                                      20.0
# 1008                                      17.5
#
#       away_team_avg_runs_scored_last_5  away_team_avg_runs_conceded_last_5  \
# 974                           0.000000                            0.000000
# 987                         207.000000                          240.000000
# 996                         186.000000                          209.000000
# 1000                        160.666667                          175.666667
# 1008                        167.250000                          178.750000
#
#       away_team_win_ratio_last_5  away_team_avg_run_rate_last_5  \
# 974                     0.000000                       0.000000
# 987                     0.000000                      10.350000
# 996                     0.000000                       9.427577
# 1000                    0.333333                       8.867211
# 1008                    0.250000                       8.987908
#
#       away_team_avg_bowl_econ_last_5  away_team_avg_boundaries_scored_last_5  \
# 974                         0.000000                                0.000000
# 987                        12.000000                               27.000000
# 996                        10.450000                               23.000000
# 1000                        8.878947                               19.333333
# 1008                        9.009211                               20.750000
#
#       away_team_avg_boundaries_conceded_last_5
# 974                                   0.000000
# 987                                  36.000000
# 996                                  30.500000
# 1000                                 24.666667
# 1008                                 24.750000

# %%
## Random forest

from sklearn.ensemble import RandomForestClassifier

# %%
for n in [25, 50, 100, 200, 500, 1000]:
    rf_model = RandomForestClassifier(
        n_estimators=n, max_depth=10, random_state=21
    )

    model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', rf_model)
    ])  

    model.fit(df_train, y_train)
    y_pred = model.predict(df_val)
    print(f" {n} :> Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")
# Out:
#  25 :> Accuracy: 0.524390243902439 , ROC: 0.5190816935002982
#  50 :> Accuracy: 0.5487804878048781 , ROC: 0.5447227191413238
#  100 :> Accuracy: 0.5121951219512195 , ROC: 0.5086463923673226
#  200 :> Accuracy: 0.5121951219512195 , ROC: 0.5050685748360167
#  500 :> Accuracy: 0.5 , ROC: 0.4922480620155039
#  1000 :> Accuracy: 0.4878048780487805 , ROC: 0.4806201550387597

# %%
for d in [5, 8, 10, 12, 15, 20, 50]:
    rf_model = RandomForestClassifier(
        n_estimators=500, max_depth=d, random_state=21
    )

    model = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', rf_model)
    ])  

    model.fit(df_train, y_train)
    y_pred = model.predict(df_val)
    print(f" {d} :> Accuracy: {accuracy_score(y_val, y_pred)} , ROC: {roc_auc_score(y_val, y_pred)} ")
# Out:
#  5 :> Accuracy: 0.5 , ROC: 0.4910554561717352
#  8 :> Accuracy: 0.4634146341463415 , ROC: 0.4537865235539654
#  10 :> Accuracy: 0.5 , ROC: 0.4922480620155039
#  12 :> Accuracy: 0.5 , ROC: 0.4922480620155039
#  15 :> Accuracy: 0.5121951219512195 , ROC: 0.5062611806797853
#  20 :> Accuracy: 0.4878048780487805 , ROC: 0.4794275491949911
#  50 :> Accuracy: 0.4634146341463415 , ROC: 0.4537865235539654

# %%
X_train_transformed = model.named_steps['preprocessor'].transform(df_train)
print(X_train_transformed.shape)
# Out:
# (743, 27)

# %%
cat_cols = model.named_steps['preprocessor'].named_transformers_['cat']\
               .named_steps['onehot'].get_feature_names_out()
num_cols = num_cols  # from your code
print("Categorical columns after one-hot:", cat_cols)
# Out:
# Categorical columns after one-hot: ['day_night_play_' 'day_night_play_d/n' 'day_night_play_dsc'
#  'day_night_play_n' 'decision_' 'decision_bat_first' 'decision_bowl_first'
#  'decision_no_toss']
